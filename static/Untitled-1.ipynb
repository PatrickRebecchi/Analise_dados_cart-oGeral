# %%
import pandas as pd

print("Online!")
# Out:
# Online!

# %%
df_clientes = pd.read_csv("ClientesBanco.csv", encoding="latin1")
display(df_clientes.head())
# Out:
#    CLIENTNUM Categoria  Idade Sexo  Dependentes           Educação  \
# 0  768805383   Cliente     45    M            3       Ensino Médio
# 1  818770008   Cliente     49    F            5    Ensino Superior
# 2  713982108   Cliente     51    M            3    Ensino Superior
# 3  769911858   Cliente     40    F            4       Ensino Médio
# 4  709106358   Cliente     40    M            3  Sem ensino formal
#
#     Estado Civil Faixa Salarial Anual Categoria Cartão  Meses como Cliente  \
# 0         Casado          $60K - $80K             Blue                  39
# 1       Solteiro       Less than $40K             Blue                  44
# 2         Casado         $80K - $120K             Blue                  36
# 3  Não informado       Less than $40K             Blue                  34
# 4         Casado          $60K - $80K             Blue                  21
#
#    ...  Inatividade 12m  Contatos 12m   Limite  Limite Consumido  \
# ...

# %%
df_total_clientes_por_sexo = df_clientes["Sexo"].value_counts().plot(kind="pie")
display(df_total_clientes_por_sexo)
# Out:
# <Axes: >

# %%
df_cliente = pd.read_csv("ClientesBanco.csv", encoding="latin1")
df_produtos_contratados = df_cliente["Produtos Contratados"].value_counts().reset_index()

display(df_produtos_contratados)
# Out:
#    Produtos Contratados  count
# 0                     3   2305
# 1                     4   1912
# 2                     5   1891
# 3                     6   1866
# 4                     2   1243
# 5                     1    910

# %%
df_filtrado = df_cliente[(df_cliente["Sexo"] == "F") 
                             & (df_cliente["Categoria Cartão"] == "Blue")]
display(df_filtrado)
# Out:
#        CLIENTNUM  Categoria  Idade Sexo  Dependentes           Educação  \
# 1      818770008    Cliente     49    F            5    Ensino Superior
# 3      769911858    Cliente     40    F            4       Ensino Médio
# 14     712396908    Cliente     57    F            2    Ensino Superior
# 19     709327383    Cliente     45    F            2    Ensino Superior
# 21     708508758  Cancelado     62    F            0    Ensino Superior
# ...          ...        ...    ...  ...          ...                ...
# 10105  709646433  Cancelado     59    F            1       Ensino Médio
# 10106  717494358    Cliente     58    F            0    Ensino Superior
# 10119  716893683  Cancelado     55    F            3  Sem ensino formal
# 10121  713899383    Cliente     56    F            1    Ensino Superior
# 10124  716506083  Cancelado     44    F            1       Ensino Médio
#
#         Estado Civil Faixa Salarial Anual Categoria Cartão  \
# ...

# %%
display(df_cliente["Categoria Cartão"].value_counts())
# Out:
# Categoria Cartão
# Blue        9435
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64

# %%
df_clientes_cancelados = df_cliente[df_cliente["Categoria"] == "Cancelado"].value_counts().reset_index()
display(df_clientes_cancelados)
# Out:
#       CLIENTNUM  Categoria  Idade Sexo  Dependentes           Educação  \
# 0     708508758  Cancelado     62    F            0    Ensino Superior
# 1     708300483  Cancelado     66    F            0          Doutorado
# 2     779471883  Cancelado     54    F            1    Ensino Superior
# 3     714374133  Cancelado     56    M            2    Ensino Superior
# 4     712030833  Cancelado     48    M            2    Ensino Superior
# ...         ...        ...    ...  ...          ...                ...
# 1622  716893683  Cancelado     55    F            3  Sem ensino formal
# 1623  710638233  Cancelado     41    M            2      Não informado
# 1624  716506083  Cancelado     44    F            1       Ensino Médio
# 1625  717406983  Cancelado     30    M            2    Ensino Superior
# 1626  714337233  Cancelado     43    F            2    Ensino Superior
#
#        Estado Civil Faixa Salarial Anual Categoria Cartão  Meses como Cliente  \
# ...

# %%
display(df_cliente["Categoria"].value_counts())
# Out:
# Categoria
# Cliente      8500
# Cancelado    1627
# Name: count, dtype: int64
